# %%
import warnings
import time
warnings.simplefilter('ignore')

import logging
logging.basicConfig(format='%(levelname)-8s [%(asctime)s] (%(module)s : %(funcName)s) %(message)s',level=logging.INFO)
logging.info("application started")
logging.info("")
logging.info("")
# будем отображать графики прямо в jupyter'e
# %pylab inline
#увеличим дефолтный размер графиков
from pylab import rcParams
rcParams['figure.figsize'] = 8, 5

import pandas as pd
import seaborn as sns

sns.set(rc=rcParams)
sns.set_style("darkgrid", {
    "axes.facecolor": "#282828",
    "axes.edgecolor":"#282828",
    "grid.color":"#298F4A",
    "xtick.color":"1",
    "ytick.color":"1",
    "text.color":"1",
    "axes.labelcolor":"1",
    "figure.facecolor":"#282828"
})
sns.set_palette(sns.color_palette("BrBG", 7))

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
# Out:
# INFO     [2017-07-20 14:09:19,791] (<ipython-input-1-e86ed4fc6502> : <module>) application started
# INFO     [2017-07-20 14:09:19,794] (<ipython-input-1-e86ed4fc6502> : <module>)
# INFO     [2017-07-20 14:09:19,796] (<ipython-input-1-e86ed4fc6502> : <module>)
# Populating the interactive namespace from numpy and matplotlib

# %%
renameCommand={"Random":"Вологда",
"Оптима":"Оптима (The Best)",
"Вороны":"Открытие, закрытие, приход, расход – 1 «Вороны»",
"Пеньки":"Пеньки (Череповец-2)",
"Мэджик":"РТЭК-4",
"Команда Ладога":"Ладога",
"BrainStorm":"Команда BrainStorm",
"Госуслуги":"Федеральные",
"Transfer Pension WEB":"Инфо сервисы",
"Уроборос":"Уроборос (Череповец-6)",
"Архонты":"Доверенности (Архонты)",
"Олимпийцы":"Олимпийцы (The Perfect)",
"Феникс ":"Феникс ",
"Викинги":"ЕФС. Вклады. Базовые сервисы «Викинги»",
"Базовые сервисы постпродажное обслуживание «Призраки»":"Призраки",
"Зилот":"Зилот ",
"Подбор продуктов 1":"Подбор Продутов 1",
"Волга":"Команда Волга",
"Геллитроны":"Открытие, закрытие, приход, расход – 2 «Геллитроны»",
"Космонавты":"Космонавты ",
"Пакет услуг":"Пакеты Услуг",
"Store & Sales Web":"Витрина продаж",
"Ядро архитектуры уведомлений":"Notifly"}

renamecolumns={
"3 спринт Committed":"26.3 Commitment",
"3 спринт Completed":"26.3 Completed",
"4 спринт Committed":"26.4 Commitment",
"4 спринт Completed":"26.4 Completed",
"Пройдено бэклога ПИР26 4 СПРИНТ":"26.4 Бэклог",
"Пройденная дистанция СПРИНТ 3":"26.3 Пройденная дистанция",
"Пройденная дистанция СПРИНТ 4":"26.4 Пройденная дистанция",
"% прохождения тестов на МСВ СПРИНТ 4":"26.4 Автотесты",
"Архревью 3 СПРИНТ":"26.3 архревью",
"Архревью 4 СПРИНТ":"26.4 архревью",
"Бэклог ПИР26   5 СПРИНТ":"26.5 Бэклог",
"5 спринт Committed":"26.5 Commitment",
"5 спринт Completed":"26.5 Completed",
"Пройдено бэклога ПИР26 5 СПРИНТ":"26.5 Пройдено",
" Пройденная дистанция, 5 СПРИНТ":"26.5 Пройденная дистанция",
"Архревью 5 СПРИНТ":"26.5 Архревью",
"% прохождения тестов на МСВ 5 СПРИНТ":"26.5 Автотесты",
"Бэклог ПИР26   6 СПРИНТ":"26.6 Беклог",
"6 спринт Committed":"26.6 Commitment",
"6 спринт Completed":"26.6 Completed",
"Пройдено бэклога ПИР26 6 СПРИНТ":"26.6 Пройдено",
"Пройденная дистанция, 6 СПРИНТ":"26.6 Пройденная дистанция",
27.5 Комментарий Jira
27.5 Комментарий автотесты
27.5 МСВ
27.5 Дизайн ревью
27.6 Комментарий Jira
27.6 Комментарий автотесты
27.6 МСВ
27.6 Дизайн ревью""".split("\n")

importantColumns2=['Команда','3 спринт Committed', '3 спринт Completed',
       '4 спринт Committed',
       '4 спринт Completed', 'Пройдено бэклога ПИР26 4 СПРИНТ',
       'Пройденная дистанция СПРИНТ 3', 'Пройденная дистанция СПРИНТ 4',
       'Rework СПРИНТ 4', 'Объем реворка ПИР26  по командам, СПРИНТ 4 ',
       'Комментарий по Jira СПРИНТ 4', '% прохождения тестов на МСВ СПРИНТ 4',
       'МСВ СПРИНТ 4', 'Комментарий по МСВ СПРИНТ 4', 'Архревью 3 СПРИНТ',
       'Архревью 4 СПРИНТ', 'Комментарий по Архревью 4 СПРИНТ',
       'Покрытие Unit-тестами 3 СПРИНТ', 'Покрытие Unit-тестами 4 СПРИНТ',
       'Комментарий Unit-тестам 4 СПРИНТ', 'Плотность дефектов 4 СПРИНТ',
       'MTTR 4 СПРИНТ', 'Бэклог ПИР26   5 СПРИНТ', '5 спринт Committed',
       '5 спринт Completed', 'Пройдено бэклога ПИР26 5 СПРИНТ',
       ' Пройденная дистанция, 5 СПРИНТ', 'Комментарий по Jira',
       'Архревью 5 СПРИНТ', 'Комментарий Архревью 5 СПРИНТ',
       'Покрытие Unit-тестами 5 СПРИНТ',
       '% прохождения тестов на МСВ 5 СПРИНТ', 'МСВ 5 СПРИНТ',
       'Бэклог ПИР26   6 СПРИНТ', '6 спринт Committed', '6 спринт Completed',
       'Пройдено бэклога ПИР26 6 СПРИНТ', 'Пройденная дистанция, 6 СПРИНТ',
       'Комментарий по Jira 6 СПРИНТ', 'Архревью 6 СПРИНТ',
       'Покрытие Unit-тестами 6 СПРИНТ',
       '% прохождения тестов на МСВ 6 СПРИНТ', 'МСВ 6 СПРИНТ',
       'Бэклог ПИР26   7 СПРИНТ', '7 спринт Committed', '7 спринт Completed',
       'Пройдено бэклога ПИР26 7 СПРИНТ', 'Комментарий Jira 7 СПРИНТ',
       'Пройденная дистанция, 7 СПРИНТ', 'Архревью 7 СПРИНТ',
       'Покрытие Unit-тестами 7 СПРИНТ',
       '% прохождения тестов на МСВ 7 СПРИНТ', 'МСВ 7 СПРИНТ']

# %%
pd1  = pd.read_csv('./data/ПИР27-6.csv',delimiter=';',encoding='UTF-8')[importantColumns1]
pd1=pd1.set_index("Команда")

pd2  = pd.read_csv('./data/ПИР26-7.csv',delimiter=';',encoding='UTF-8')[importantColumns2]
pd2=pd2.rename(columns=renamecolumns)
pd2=pd2.set_index("Команда")

pd2=pd2.applymap(lambda x: renameCommand.get(x,x))
# pd2.head()

# %%
fullTable=pd1.join(pd2,lsuffix="L")
for i in delCols:
    del fullTable[i]
    
# fullTable[[x for x in fullTable.columns if 'Пройдено' in x]]

# %%
def process(x):
    x=str(x).replace(',','.')
    if str(x)[-1]=='%':
        return float(x[:-1])/100
    else:
        try:
            return float(x)
        except Exception as e:
            return 0.0
fullTable=fullTable.applymap(process)
fullTable=fullTable.fillna(0)

table27=fullTable[[x for x in fullTable.columns if '27' in x]]
table26=fullTable[[x for x in fullTable.columns if '26' in x]]

table26.to_csv('./data/26.csv')
table27.to_csv('./data/27.csv')
#table26;
#table27;
